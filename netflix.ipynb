# %%
import pandas as pd

# %%
# Leer el archivo CSV
df = pd.read_csv('/content/Netflix.ipy/netflix_titles.csv')

# Ver columnas actuales
print(df.columns)
# Out:
# Index(['show_id', 'type', 'title', 'director', 'cast', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in', 'description'],
#       dtype='object')

# %%
# Traducción de columnas
traduccion = {
    'show_id': 'id_programa',
    'type': 'tipo',
    'title': 'titulo',
    'director': 'director',
    'cast': 'reparto',
    'country': 'pais',
    'date_added': 'fecha_agregada',
    'release_year': 'anio_lanzamiento',
    'rating': 'clasificacion',
    'duration': 'duracion',
    'listed_in': 'categoria',
    'description': 'descripcion'
}

# Renombrar columnas
df.rename(columns=traduccion, inplace=True)

# Ver resultado
print(df.head())
# Out:
#   id_programa     tipo                 titulo         director  \
# 0          s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1          s2  TV Show          Blood & Water              NaN
# 2          s3  TV Show              Ganglands  Julien Leclercq
# 3          s4  TV Show  Jailbirds New Orleans              NaN
# 4          s5  TV Show           Kota Factory              NaN
#
#                                              reparto           pais  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#        fecha_agregada  anio_lanzamiento clasificacion   duracion  \
# 0  September 25, 2021              2020         PG-13     90 min
# ...
