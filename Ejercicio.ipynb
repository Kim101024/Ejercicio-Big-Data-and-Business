# %%
a = float(input("Ingrese el valor de a: "))
b = float(input("Ingrese el valor de b: "))

resultado = (((a + b) / 5) ** 2) / 2

print(f"El resultado es: {resultado:.4f}")
# Out:
# Ingrese el valor de a: 15.3333
# Ingrese el valor de b: 1
# El resultado es: 5.3355
